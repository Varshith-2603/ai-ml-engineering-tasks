# %%
import pandas as pd
import numpy as np
data = np.array(['g','e','e','k','s'])
s = pd.Series(data)
print(s)
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: str

# %%
import pandas as pd
dicts = {"Name":["Nikhil","Lohith","Yashwanth","Varshith"],
         "Age":[32,27,26,21],
         "Gender":["Male","Male","Male","Male"]
        }
df = pd.DataFrame(dicts)
df
# Out:
#         Name  Age Gender
# 0     Nikhil   32   Male
# 1     Lohith   27   Male
# 2  Yashwanth   26   Male
# 3   Varshith   21   Male
