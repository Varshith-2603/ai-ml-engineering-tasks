# %%
#1
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#2
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df.head(8)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# ...

# %%
#3
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df.tail(12)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9988       9989    15589329      Pirozzi          775    France    Male   30
# 9989       9990    15605622     McMillan          841     Spain    Male   28
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9994       9995    15719294         Wood          800    France  Female   29
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# 9996       9997    15569892    Johnstone          516    France    Male   35
# 9997       9998    15584532          Liu          709    France  Female   36
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
# ...

# %%
#4
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df.sample(n=10)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 7172       7173    15682540  Cremonesi          602    France  Female   33
# 7416       7417    15592326      Baker          583    France    Male   36
# 7731       7732    15629273        Lin          638   Germany    Male   42
# 5740       5741    15568885      Scott          620   Germany  Female   34
# 8892       8893    15739476    Ferrari          680    France  Female   32
# 6011       6012    15783007     Parker          520   Germany  Female   45
# 5941       5942    15791030    Edwards          612    France  Female   33
# 5463       5464    15750099   Marshall          731    France  Female   36
# 3920       3921    15620268    Thomson          634   Germany    Male   43
# 7024       7025    15714087     McGill          624   Germany  Female   45
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 7172       8       0.00              2          1               1
# ...

# %%
#5
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df.shape
# Out:
# (10000, 14)

# %%
#6
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  str
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  str
#  5   Gender           10000 non-null  str
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), str(3)
# memory usage: 1.1 MB

# %%
#7
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='str')

# %%
#8
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender                 str
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
#9
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
print(df.isnull().sum())
print("\nusing isna():\n",df.isna().sum())
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64
#
# using isna():
#  RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#10
import pandas as pd
df = pd.read_csv("Bank_customer_churn - Bank_customer_churn.csv")
df['CreditScore']
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: CreditScore, Length: 10000, dtype: int64

# %%
#11
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df[['CustomerId','Surname','Balance','Exited']]
# Out:
#       CustomerId    Surname    Balance  Exited
# 0       15634602   Hargrave       0.00       1
# 1       15647311       Hill   83807.86       0
# 2       15619304       Onio  159660.80       1
# 3       15701354       Boni       0.00       0
# 4       15737888   Mitchell  125510.82       0
# ...          ...        ...        ...     ...
# 9995    15606229   Obijiaku       0.00       0
# 9996    15569892  Johnstone   57369.61       0
# 9997    15584532        Liu       0.00       1
# 9998    15682355  Sabbatini   75075.31       1
# 9999    15628319     Walker  130142.79       0
#
# [10000 rows x 4 columns]

# %%
#12
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df.select_dtypes(include=['int']).columns
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'Exited'],
#       dtype='str')

# %%
#13
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
#14
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
print(df.duplicated())
print("/n Dropping Duplicates:",df.drop_duplicates())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool
# /n Dropping Duplicates:       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# ...

# %%
#15
import pandas as pd
df = pd.read_csv('Bank_customer_churn - Bank_customer_churn.csv')
df.value_counts('Exited')
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64
